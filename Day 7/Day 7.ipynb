# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("general_data.csv")

# %% [markdown]
# printing first 10 columns of the data set

# %%
data.head(10)
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
# 2   32        No  Travel_Frequently  Research & Development                17
# 3   38        No         Non-Travel  Research & Development                 2
# 4   32        No      Travel_Rarely  Research & Development                10
# 5   46        No      Travel_Rarely  Research & Development                 8
# 6   28       Yes      Travel_Rarely  Research & Development                11
# 7   29        No      Travel_Rarely  Research & Development                18
# 8   31        No      Travel_Rarely  Research & Development                 1
# 9   25        No         Non-Travel  Research & Development                 7
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# ...

# %% [markdown]
# printing last ten columns of the csv

# %%
data.tail(10)
# Out:
#       Age Attrition     BusinessTravel              Department  \
# 4400   37        No      Travel_Rarely  Research & Development
# 4401   45        No  Travel_Frequently                   Sales
# 4402   37       Yes  Travel_Frequently                   Sales
# 4403   39        No  Travel_Frequently  Research & Development
# 4404   29        No      Travel_Rarely                   Sales
# 4405   42        No      Travel_Rarely  Research & Development
# 4406   29        No      Travel_Rarely  Research & Development
# 4407   25        No      Travel_Rarely  Research & Development
# 4408   42        No      Travel_Rarely                   Sales
# 4409   40        No      Travel_Rarely  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 4400                22          5        Medical              1        4401
# 4401                21          1      Marketing              1        4402
# ...

# %% [markdown]
# printing column names of the csv

# %%
data.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EmployeeCount', 'EmployeeID', 'Gender',
#        'JobLevel', 'JobRole', 'MaritalStatus', 'MonthlyIncome',
#        'NumCompaniesWorked', 'Over18', 'PercentSalaryHike', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'YearsAtCompany', 'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %% [markdown]
# about each column - values in each column, null/not null, type of entries

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4410 entries, 0 to 4409
# Data columns (total 24 columns):
# Age                        4410 non-null int64
# Attrition                  4410 non-null object
# BusinessTravel             4410 non-null object
# Department                 4410 non-null object
# DistanceFromHome           4410 non-null int64
# Education                  4410 non-null int64
# EducationField             4410 non-null object
# EmployeeCount              4410 non-null int64
# EmployeeID                 4410 non-null int64
# Gender                     4410 non-null object
# JobLevel                   4410 non-null int64
# JobRole                    4410 non-null object
# MaritalStatus              4410 non-null object
# MonthlyIncome              4410 non-null int64
# NumCompaniesWorked         4391 non-null float64
# Over18                     4410 non-null object
# PercentSalaryHike          4410 non-null int64
# ...

# %% [markdown]
# printing a few statistics related to the dataset

# %% [markdown]
# finding measures of central tendencies

# %%
data.select_dtypes(include='int64').mean()
# Out:
# Age                           36.923810
# DistanceFromHome               9.192517
# Education                      2.912925
# EmployeeCount                  1.000000
# EmployeeID                  2205.500000
# JobLevel                       2.063946
# MonthlyIncome              65029.312925
# PercentSalaryHike             15.209524
# StandardHours                  8.000000
# StockOptionLevel               0.793878
# TrainingTimesLastYear          2.799320
# YearsAtCompany                 7.008163
# YearsSinceLastPromotion        2.187755
# YearsWithCurrManager           4.123129
# dtype: float64

# %%
data.select_dtypes(include='int64').median()
# Out:
# Age                           36.0
# DistanceFromHome               7.0
# Education                      3.0
# EmployeeCount                  1.0
# EmployeeID                  2205.5
# JobLevel                       2.0
# MonthlyIncome              49190.0
# PercentSalaryHike             14.0
# StandardHours                  8.0
# StockOptionLevel               1.0
# TrainingTimesLastYear          3.0
# YearsAtCompany                 5.0
# YearsSinceLastPromotion        1.0
# YearsWithCurrManager           3.0
# dtype: float64

# %%
data.select_dtypes(include='int64').mode()
# Out:
#        Age  DistanceFromHome  Education  EmployeeCount  EmployeeID  JobLevel  \
# 0     35.0               2.0        3.0            1.0           1       1.0
# 1      NaN               NaN        NaN            NaN           2       NaN
# 2      NaN               NaN        NaN            NaN           3       NaN
# 3      NaN               NaN        NaN            NaN           4       NaN
# 4      NaN               NaN        NaN            NaN           5       NaN
# ...    ...               ...        ...            ...         ...       ...
# 4405   NaN               NaN        NaN            NaN        4406       NaN
# 4406   NaN               NaN        NaN            NaN        4407       NaN
# 4407   NaN               NaN        NaN            NaN        4408       NaN
# 4408   NaN               NaN        NaN            NaN        4409       NaN
# 4409   NaN               NaN        NaN            NaN        4410       NaN
#
# ...

# %% [markdown]
# Printing the statistics using describe function

# %%
data.describe()
# Out:
#                Age  DistanceFromHome    Education  EmployeeCount   EmployeeID  \
# count  4410.000000       4410.000000  4410.000000         4410.0  4410.000000
# mean     36.923810          9.192517     2.912925            1.0  2205.500000
# std       9.133301          8.105026     1.023933            0.0  1273.201673
# min      18.000000          1.000000     1.000000            1.0     1.000000
# 25%      30.000000          2.000000     2.000000            1.0  1103.250000
# 50%      36.000000          7.000000     3.000000            1.0  2205.500000
# 75%      43.000000         14.000000     4.000000            1.0  3307.750000
# max      60.000000         29.000000     5.000000            1.0  4410.000000
#
#           JobLevel  MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  \
# count  4410.000000    4410.000000         4391.000000        4410.000000
# mean      2.063946   65029.312925            2.694830          15.209524
# ...

# %% [markdown]
# finding if there are any duplicae entries and then deleting them

# %%
data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4405    False
# 4406    False
# 4407    False
# 4408    False
# 4409    False
# Length: 4410, dtype: bool

# %%
data.drop_duplicates()
# Out:
#       Age Attrition     BusinessTravel              Department  \
# 0      51        No      Travel_Rarely                   Sales
# 1      31       Yes  Travel_Frequently  Research & Development
# 2      32        No  Travel_Frequently  Research & Development
# 3      38        No         Non-Travel  Research & Development
# 4      32        No      Travel_Rarely  Research & Development
# ...   ...       ...                ...                     ...
# 4405   42        No      Travel_Rarely  Research & Development
# 4406   29        No      Travel_Rarely  Research & Development
# 4407   25        No      Travel_Rarely  Research & Development
# 4408   42        No      Travel_Rarely                   Sales
# 4409   40        No      Travel_Rarely  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                    6          2  Life Sciences              1           1
# ...

# %%
data.select_dtypes(include ='object').describe()
# Out:
#        Attrition BusinessTravel              Department EducationField Gender  \
# count       4410           4410                    4410           4410   4410
# unique         2              3                       3              6      2
# top           No  Travel_Rarely  Research & Development  Life Sciences   Male
# freq        3699           3129                    2883           1818   2646
#
#                 JobRole MaritalStatus Over18
# count              4410          4410   4410
# unique                9             3      1
# top     Sales Executive       Married      Y
# freq                978          2019   4410

# %% [markdown]
# printing and plotting methods of dispersion

# %%
data.select_dtypes(include='int64').var()
# Out:
# Age                        8.341719e+01
# DistanceFromHome           6.569144e+01
# Education                  1.048438e+00
# EmployeeCount              0.000000e+00
# EmployeeID                 1.621042e+06
# JobLevel                   1.224760e+00
# MonthlyIncome              2.215480e+09
# PercentSalaryHike          1.338907e+01
# StandardHours              0.000000e+00
# StockOptionLevel           7.257053e-01
# TrainingTimesLastYear      1.661465e+00
# YearsAtCompany             3.751728e+01
# YearsSinceLastPromotion    1.037935e+01
# YearsWithCurrManager       1.272582e+01
# dtype: float64

# %%
data.select_dtypes(include='int64').skew()
# Out:
# Age                        0.413005
# DistanceFromHome           0.957466
# Education                 -0.289484
# EmployeeCount              0.000000
# EmployeeID                 0.000000
# JobLevel                   1.024703
# MonthlyIncome              1.368884
# PercentSalaryHike          0.820569
# StandardHours              0.000000
# StockOptionLevel           0.968321
# TrainingTimesLastYear      0.552748
# YearsAtCompany             1.763328
# YearsSinceLastPromotion    1.982939
# YearsWithCurrManager       0.832884
# dtype: float64

# %%
plt.hist(data.Education)
# Out:
# (array([ 510.,    0.,  846.,    0.,    0., 1716.,    0., 1194.,    0.,
#          144.]),
#  array([1. , 1.4, 1.8, 2.2, 2.6, 3. , 3.4, 3.8, 4.2, 4.6, 5. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# Inference - coefficient for skewness for Education is negative and thus it is Negatively Skewd or left Skewed which has been shown with the help of histogram

# %%
plt.hist(data.YearsWithCurrManager)
# Out:
# (array([1017., 1458.,  387.,   87.,  969.,  273.,   66.,   96.,   30.,
#           27.]),
#  array([ 0. ,  1.7,  3.4,  5.1,  6.8,  8.5, 10.2, 11.9, 13.6, 15.3, 17. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# Inference - coefficient for skewness for YearwithCurrManager is positive and thus it is Positively Skewd or right Skewed which has been shown with the help of histogram

# %%
plt.hist(data.StandardHours)
# Out:
# (array([   0.,    0.,    0.,    0.,    0., 4410.,    0.,    0.,    0.,
#            0.]),
#  array([7.5, 7.6, 7.7, 7.8, 7.9, 8. , 8.1, 8.2, 8.3, 8.4, 8.5]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# Inference - coefficient for skewness for StanadardHours is zero and thus the data is normally distributed

# %%
data.select_dtypes(include='int64').kurt()
# Out:
# Age                       -0.405951
# DistanceFromHome          -0.227045
# Education                 -0.560569
# EmployeeCount              0.000000
# EmployeeID                -1.200000
# JobLevel                   0.395525
# MonthlyIncome              1.000232
# PercentSalaryHike         -0.302638
# StandardHours              0.000000
# StockOptionLevel           0.361086
# TrainingTimesLastYear      0.491149
# YearsAtCompany             3.923864
# YearsSinceLastPromotion    3.601761
# YearsWithCurrManager       0.167949
# dtype: float64

# %% [markdown]
# Inference - nagative value of the coefficient means the curve is flat, zero value denotes normal curve and positive value denotes peakness

# %% [markdown]
# checking for outliers

# %%
plt.boxplot(data.PercentSalaryHike)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1c54915e2c8>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1c55c9b0d48>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1c549189788>],
#  'medians': [<matplotlib.lines.Line2D at 0x1c549172688>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1c549168308>],
#  'means': []}

# %% [markdown]
# Inference - here median is below the centre thus it is right skewed without any outliers

# %%
plt.boxplot(data.EmployeeCount)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1c55c8a31c8>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1c55c8a3188>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1c55c8a3488>],
#  'medians': [<matplotlib.lines.Line2D at 0x1c55c8c3e88>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1c55c8c3f08>],
#  'means': []}

# %%
plt.boxplot(data.MonthlyIncome)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1c5471c3708>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1c5471c3d88>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1c55c8e2408>],
#  'medians': [<matplotlib.lines.Line2D at 0x1c54719ddc8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1c54719dec8>],
#  'means': []}

# %% [markdown]
# Inference - the curve has several outliers

# %%
plt.scatter(data.MonthlyIncome,data.PercentSalaryHike)

# %%
plt.scatter(data.YearsAtCompany,data.YearsSinceLastPromotion)
